# %% [markdown]
# # Limpieza de Base de Datos de Hechos Delictivos en Argentina (2017-2021)
#
# En este documento Markdown se describirá el proceso de limpieza de una base de datos de hechos delictivos ocurridos en Argentina durante el período comprendido entre los años 2017 y 2021. El objetivo de esta limpieza es obtener información relevante para responder las siguientes preguntas:
#
# 1. ¿Cuál es la proporción de víctimas masculinas y femeninas en los delitos registrados?
# 2. ¿Cuáles son los departamentos con mayor número de delitos?
# 3. ¿Cuáles son los motivos más comunes que originaron el registro de un delito?
# 4. ¿Existe alguna relación entre el mes del año y la cantidad de delitos?
# 5. ¿Hay alguna relación entre el lugar y el género del inculpado?
# 6. ¿Hay alguna relación entre el lugar y el género de la víctima?
#
# ## Recopilación de la base de datos
#
# Se trabaja con una base de datos  sobre los hechos delictivos ocurridos en Argentina entre los años 2017 y 2021.
#
# ## Analisis y Limpieza de datos
#
# - Analizar los tipos de datos presentes en el dataframe y realizar una primera visualización para obtener una visión general de los datos.
#
# ### Información del dataframe y verificación de datos nulos
#
# - Obtener información detallada sobre el dataframe, incluyendo la cantidad de datos en cada fila y la presencia de valores nulos, se puede utilizar el método `info()`. A continuación se muestra el código necesario:
#
# ### Limpieza
# - Eliminar registros duplicados: Se eliminarán aquellos registros que sean duplicados para evitar distorsiones en los análisis posteriores.

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/ianCristianAriel/proc_datos_proyecto_final_G3/main/datos/brutos/SAT-HD-BU_2017-2021.csv'
dataframe = pd.read_csv(url)

print(dataframe.head())
# Out:
#    Id_hecho federal  Cod_INDEC_Prov provincia  codigo_departamento  Cod_INDEC  \
# 0     11535      No              58   NEUQUEN                   35      58035
# 1     11535      No              58   NEUQUEN                   35      58035
# 2     11535      No              58   NEUQUEN                   35      58035
# 3     11535      No              58   NEUQUEN                   35      58035
# 4     11536      No              58   NEUQUEN                   35      58035
#
#   departamento  localidad codigo_localidad  radio_censal  ...  \
# 0  Confluencia   Plottier              100           NaN  ...
# 1  Confluencia   Plottier              100           NaN  ...
# 2  Confluencia   Plottier              100           NaN  ...
# 3  Confluencia   Plottier              100           NaN  ...
# 4  Confluencia  Cutral Có               40           NaN  ...
#
#    identidad_genero_inculpado  otro_identidad_genero_inculpado  \
# 0                       Varón                              NaN
# 1                       Varón                              NaN
# 2                       Varón                              NaN
# 3              No corresponde                          -------
# 4                       Varón                              NaN
#
#    tr_edad_inculpado    clase_inculpado otro_clase_inculpado  \
# 0     Sin determinar  Sin determinación                  NaN
# 1     Sin determinar  Sin determinación                  NaN
# 2     Sin determinar  Sin determinación                  NaN
# 3     No corresponde     No corresponde                 ----
# 4              30-34              Civil                  NaN
#
#   relacion_inculpado_victima relacion_victima_inculpado  \
# 0               Sin relación             No corresponde
# 1               Sin relación             No corresponde
# 2               Sin relación             No corresponde
# 3             No corresponde               Sin relación
# 4               Sin relación             No corresponde
#
#   tipo_hecho_segun_victima cant_inc cant_vic
# 0                 HD Varón        3        1
# 1                 HD Varón        3        1
# 2                 HD Varón        3        1
# 3                 HD Varón        3        1
# 4                 HD Varón        2        1
#
# [5 rows x 46 columns]
# C:\Users\elcoy\AppData\Local\Temp\ipykernel_15216\1940262427.py:4: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframe = pd.read_csv(url)

# %% [markdown]
# ### Averiguo el tamaño del dataframe (Filas x Columnas)
#
# Para obtener el tamaño del dataframe y conocer la cantidad de filas y columnas, se puede utilizar la propiedad `shape` del dataframe. A continuación se muestra el código necesario:
#
# ```python
# data.shape

# %%
dataframe.shape ###( Filas x Columnas)
# Out:
# (25160, 46)

# %% [markdown]
# ### Tipos de datos presentes en el dataframe
#
# Para conocer los tipos de datos presentes en el dataframe, se puede utilizar el atributo `dtypes`. A continuación se muestra el código necesario:
#
# ```python
# data.dtypes

# %%
### Que tipos de datos tengo
dataframe.dtypes
# Out:
# Id_hecho                              int64
# federal                              object
# Cod_INDEC_Prov                        int64
# provincia                            object
# codigo_departamento                   int64
# Cod_INDEC                             int64
# departamento                         object
# localidad                            object
# codigo_localidad                     object
# radio_censal                        float64
# latitud_radio                       float64
# longitud_radio                      float64
# anio                                  int64
# mes                                   int64
# tipo_lugar                           object
# otro_tipo_lugar                      object
# tipo_lugar_ampliado                  object
# clase_arma                           object
# otro_clase_arma                      object
# en_ocasion_otro_delito               object
# otro_en_ocasion_otro_delito          object
# motivo_origen_registro               object
# otro_motivo_origen_registro          object
# fecha_hecho                          object
# hora_hecho                           object
# tipo_persona_id                      object
# tipo_persona                         object
# sexo_victima                         object
# identidad_genero_victima             object
# otro_identidad_genero_victima        object
# tr_edad_victima                      object
# clase_victima                        object
# otro_clase_victima                   object
# situacion_ocupacional_victima        object
# otro_situacion_ocupacional_victi     object
# sexo_inculpado                       object
# identidad_genero_inculpado           object
# otro_identidad_genero_inculpado      object
# tr_edad_inculpado                    object
# clase_inculpado                      object
# otro_clase_inculpado                 object
# relacion_inculpado_victima           object
# relacion_victima_inculpado           object
# tipo_hecho_segun_victima             object
# cant_inc                              int64
# cant_vic                              int64
# dtype: object

# %% [markdown]
# ### Visualización de las primeras filas del dataframe
#
# Para visualizar las primeras filas del dataframe y tener una idea de los datos que contiene, se puede utilizar el método `head()`. A continuación se muestra el código necesario:
#
# ```python
# data.head()

# %%
dataframe.head()
# Out:
#    Id_hecho federal  Cod_INDEC_Prov provincia  codigo_departamento  Cod_INDEC  \
# 0     11535      No              58   NEUQUEN                   35      58035
# 1     11535      No              58   NEUQUEN                   35      58035
# 2     11535      No              58   NEUQUEN                   35      58035
# 3     11535      No              58   NEUQUEN                   35      58035
# 4     11536      No              58   NEUQUEN                   35      58035
#
#   departamento  localidad codigo_localidad  radio_censal  ...  \
# 0  Confluencia   Plottier              100           NaN  ...
# 1  Confluencia   Plottier              100           NaN  ...
# 2  Confluencia   Plottier              100           NaN  ...
# 3  Confluencia   Plottier              100           NaN  ...
# 4  Confluencia  Cutral Có               40           NaN  ...
#
#    identidad_genero_inculpado  otro_identidad_genero_inculpado  \
# 0                       Varón                              NaN
# 1                       Varón                              NaN
# 2                       Varón                              NaN
# 3              No corresponde                          -------
# 4                       Varón                              NaN
#
#    tr_edad_inculpado    clase_inculpado otro_clase_inculpado  \
# 0     Sin determinar  Sin determinación                  NaN
# 1     Sin determinar  Sin determinación                  NaN
# 2     Sin determinar  Sin determinación                  NaN
# 3     No corresponde     No corresponde                 ----
# 4              30-34              Civil                  NaN
#
#   relacion_inculpado_victima relacion_victima_inculpado  \
# 0               Sin relación             No corresponde
# 1               Sin relación             No corresponde
# 2               Sin relación             No corresponde
# 3             No corresponde               Sin relación
# 4               Sin relación             No corresponde
#
#   tipo_hecho_segun_victima cant_inc cant_vic
# 0                 HD Varón        3        1
# 1                 HD Varón        3        1
# 2                 HD Varón        3        1
# 3                 HD Varón        3        1
# 4                 HD Varón        2        1
#
# [5 rows x 46 columns]

# %% [markdown]
# ### Información del dataframe y verificación de datos nulos
#
# Para obtener información detallada sobre el dataframe, incluyendo la cantidad de datos en cada fila y la presencia de valores nulos, se puede utilizar el método `info()`. A continuación se muestra el código necesario:
#
# ```python
# dataframe.info()

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25160 entries, 0 to 25159
# Data columns (total 46 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Id_hecho                          25160 non-null  int64
#  1   federal                           25160 non-null  object
#  2   Cod_INDEC_Prov                    25160 non-null  int64
#  3   provincia                         25160 non-null  object
#  4   codigo_departamento               25160 non-null  int64
#  5   Cod_INDEC                         25160 non-null  int64
#  6   departamento                      25160 non-null  object
#  7   localidad                         25160 non-null  object
#  8   codigo_localidad                  25160 non-null  object
#  9   radio_censal                      13990 non-null  float64
#  10  latitud_radio                     13990 non-null  float64
#  11  longitud_radio                    13990 non-null  float64
#  12  anio                              25160 non-null  int64
#  13  mes                               25160 non-null  int64
#  14  tipo_lugar                        25160 non-null  object
#  15  otro_tipo_lugar                   1067 non-null   object
#  16  tipo_lugar_ampliado               25160 non-null  object
#  17  clase_arma                        25160 non-null  object
#  18  otro_clase_arma                   296 non-null    object
#  19  en_ocasion_otro_delito            25160 non-null  object
#  20  otro_en_ocasion_otro_delito       1088 non-null   object
#  21  motivo_origen_registro            25160 non-null  object
#  22  otro_motivo_origen_registro       121 non-null    object
#  23  fecha_hecho                       25160 non-null  object
#  24  hora_hecho                        25160 non-null  object
#  25  tipo_persona_id                   25160 non-null  object
#  26  tipo_persona                      25160 non-null  object
#  27  sexo_victima                      25160 non-null  object
#  28  identidad_genero_victima          25160 non-null  object
#  29  otro_identidad_genero_victima     13646 non-null  object
#  30  tr_edad_victima                   25160 non-null  object
#  31  clase_victima                     25160 non-null  object
#  32  otro_clase_victima                13678 non-null  object
#  33  situacion_ocupacional_victima     25160 non-null  object
#  34  otro_situacion_ocupacional_victi  13985 non-null  object
#  35  sexo_inculpado                    25160 non-null  object
#  36  identidad_genero_inculpado        25160 non-null  object
#  37  otro_identidad_genero_inculpado   11514 non-null  object
#  38  tr_edad_inculpado                 25160 non-null  object
#  39  clase_inculpado                   25160 non-null  object
#  40  otro_clase_inculpado              11715 non-null  object
#  41  relacion_inculpado_victima        25160 non-null  object
#  42  relacion_victima_inculpado        25160 non-null  object
#  43  tipo_hecho_segun_victima          25160 non-null  object
#  44  cant_inc                          25160 non-null  int64
#  45  cant_vic                          25160 non-null  int64
# dtypes: float64(3), int64(8), object(35)
# memory usage: 8.8+ MB

# %% [markdown]
# ### Elimino los registros - Al interesarme el aspecto de la victima eligo este registro
#
# Generamos un nuevo dataframe conservando todas las columnas del original, pero solo incluyendo las filas con valores "Víctima" en la columna 'tipo_persona'. Esto nos permite tener un dataframe con información unica en dicha columna.

# %%
###Filtro el dataframe solo por victimas
df_victimas=dataframe[dataframe['tipo_persona'] == 'Víctima']

# %%
df_victimas
# Out:
#        Id_hecho federal  Cod_INDEC_Prov         provincia  \
# 3         11535      No              58           NEUQUEN
# 6         11536      No              58           NEUQUEN
# 8         11537      No              58           NEUQUEN
# 10        11538      No              58           NEUQUEN
# 12        11539      No              58           NEUQUEN
# ...         ...     ...             ...               ...
# 25150     28124      No               6      BUENOS AIRES
# 25153     28125      No               6      BUENOS AIRES
# 25155     28129      No               6      BUENOS AIRES
# 25157     28253      No              94  TIERRA DEL FUEGO
# 25159     28263      No              30        ENTRE RIOS
#
#        codigo_departamento  Cod_INDEC      departamento         localidad  \
# 3                       35      58035       Confluencia          Plottier
# 6                       35      58035       Confluencia         Cutral Có
# 8                       35      58035       Confluencia           Neuquén
# 10                      91      58091        Pehuenches         Barrancas
# 12                      35      58035       Confluencia           Neuquén
# ...                    ...        ...               ...               ...
# 25150                  868       6868     Villa Gesell      Villa Gesell
# 25153                  861       6861     Vicente López     Vicente López
# 25155                  274       6274  Florencio Varela  Florencio Varela
# 25157                   14      94014           Ushuaia           Ushuaia
# 25159                   15      30015         Concordia         Concordia
#
#       codigo_localidad  radio_censal  ...  identidad_genero_inculpado  \
# 3                  100           NaN  ...              No corresponde
# 6                   40           NaN  ...              No corresponde
# 8                   70           NaN  ...              No corresponde
# 10                  10           NaN  ...              No corresponde
# 12                  70           NaN  ...              No corresponde
# ...                ...           ...  ...                         ...
# 25150               20    68680104.0  ...              No corresponde
# 25153               10    68612406.0  ...              No corresponde
# 25155               10    62741802.0  ...              No corresponde
# 25157               20   940140712.0  ...              No corresponde
# 25159               60           NaN  ...              No corresponde
#
#        otro_identidad_genero_inculpado  tr_edad_inculpado  clase_inculpado  \
# 3                              -------     No corresponde   No corresponde
# 6                              -------     No corresponde   No corresponde
# 8                              -------     No corresponde   No corresponde
# 10                             -------     No corresponde   No corresponde
# 12                             -------     No corresponde   No corresponde
# ...                                ...                ...              ...
# 25150                          -------     No corresponde   No corresponde
# 25153                          -------     No corresponde   No corresponde
# 25155                          -------     No corresponde   No corresponde
# 25157                          -------     No corresponde   No corresponde
# 25159                          -------     No corresponde   No corresponde
#
#       otro_clase_inculpado relacion_inculpado_victima  \
# 3                     ----             No corresponde
# 6                     ----             No corresponde
# 8                     ----             No corresponde
# 10                    ----             No corresponde
# 12                    ----             No corresponde
# ...                    ...                        ...
# 25150                 ----             No corresponde
# 25153                 ----             No corresponde
# 25155                 ----             No corresponde
# 25157                 ----             No corresponde
# 25159                 ----             No corresponde
#
#            relacion_victima_inculpado tipo_hecho_segun_victima cant_inc  \
# 3                        Sin relación                 HD Varón        3
# 6                        Sin relación                 HD Varón        2
# 8                        Sin relación                 HD Varón        1
# 10                        Padre/Madre                 HD Varón        1
# 12                       Sin relación                 HD Varón        1
# ...                               ...                      ...      ...
# 25150  Otras relaciones no familiares                 HD Varón        1
# 25153                    Sin relación                 HD Varón        2
# 25155  Otras relaciones no familiares                 HD Varón        1
# 25157                 Conyuge/ pareja                 HD Varón        1
# 25159                    Sin relación                 HD Varón        1
#
#       cant_vic
# 3            1
# 6            1
# 8            1
# 10           1
# 12           1
# ...        ...
# 25150        1
# 25153        1
# 25155        1
# 25157        1
# 25159        1
#
# [11514 rows x 46 columns]
