# %%
import pandas as pd
import numpy as np
from IPython.display import display as disp

# %% [markdown]
# ### Lectura del CSV limpio

# %%
datos = pd.read_csv("../../../datos/procesados/limpieza01_argentina_delitos.csv")
disp(datos)
# Out:
#        Id_hecho         provincia         localidad  anio  mes  \
# 0         11535           NEUQUEN          Plottier  2017    1
# 1         11535           NEUQUEN          Plottier  2017    1
# 2         11535           NEUQUEN          Plottier  2017    1
# 3         11535           NEUQUEN          Plottier  2017    1
# 4         11536           NEUQUEN         Cutral Có  2017    1
# ...         ...               ...               ...   ...  ...
# 25155     28129      BUENOS AIRES  Florencio Varela  2021   11
# 25156     28253  TIERRA DEL FUEGO           Ushuaia  2021    7
# 25157     28253  TIERRA DEL FUEGO           Ushuaia  2021    7
# 25158     28263        ENTRE RIOS         Concordia  2017   12
# 25159     28263        ENTRE RIOS         Concordia  2017   12
#
#                  tipo_lugar   tipo_lugar_ampliado motivo_origen_registro  \
# 0      Domicilio particular  Domicilio particular  Intervención policial
# 1      Domicilio particular  Domicilio particular  Intervención policial
# 2      Domicilio particular  Domicilio particular  Intervención policial
# 3      Domicilio particular  Domicilio particular  Intervención policial
# 4               Vía pública           Vía pública  Intervención policial
# ...                     ...                   ...                    ...
# 25155           Vía pública           Vía pública  Intervención policial
# 25156  Domicilio particular  Domicilio particular  Intervención policial
# 25157  Domicilio particular  Domicilio particular  Intervención policial
# 25158           Vía pública           Vía pública  Intervención policial
# 25159           Vía pública           Vía pública  Intervención policial
#
#       fecha_hecho hora_hecho            tipo_persona_id tipo_persona  \
# 0       14/1/2017   22:38:00  Imputado idRegistro 12929     Imputado
# 1       14/1/2017   22:38:00  Imputado idRegistro 12930     Imputado
# 2       14/1/2017   22:38:00  Imputado idRegistro 12931     Imputado
# 3       14/1/2017   22:38:00   Víctima idRegistro 12235      Víctima
# 4        7/1/2017   10:35:00  Imputado idRegistro 12932     Imputado
# ...           ...        ...                        ...          ...
# 25155  10/11/2021   11:11:11   Víctima idRegistro 29888      Víctima
# 25156    4/7/2021   12:00:00  Imputado idRegistro 32993     Imputado
# 25157    4/7/2021   12:00:00   Víctima idRegistro 30020      Víctima
# 25158  25/12/2017   11:11:11  Imputado idRegistro 33004     Imputado
# 25159  25/12/2017   11:11:11   Víctima idRegistro 30031      Víctima
#
#          sexo_victima tr_edad_victima   clase_victima  sexo_inculpado  \
# 0      No corresponde  No corresponde  No corresponde       Masculino
# 1      No corresponde  No corresponde  No corresponde       Masculino
# 2      No corresponde  No corresponde  No corresponde       Masculino
# 3           Masculino           45-49           Civil  No corresponde
# 4      No corresponde  No corresponde  No corresponde       Masculino
# ...               ...             ...             ...             ...
# 25155       Masculino           45-49           Civil  No corresponde
# 25156  No corresponde  No corresponde  No corresponde        Femenino
# 25157       Masculino           25-29           Civil  No corresponde
# 25158  No corresponde  No corresponde  No corresponde       Masculino
# 25159       Masculino           35-39           Civil  No corresponde
#
#       tr_edad_inculpado relacion_inculpado_victima  \
# 0        Sin determinar               Sin relación
# 1        Sin determinar               Sin relación
# 2        Sin determinar               Sin relación
# 3        No corresponde             No corresponde
# 4                 30-34               Sin relación
# ...                 ...                        ...
# 25155    No corresponde             No corresponde
# 25156             25-29            Conyuge/ pareja
# 25157    No corresponde             No corresponde
# 25158             30-34               Sin relación
# 25159    No corresponde             No corresponde
#
#            relacion_victima_inculpado  cant_vic
# 0                      No corresponde         1
# 1                      No corresponde         1
# 2                      No corresponde         1
# 3                        Sin relación         1
# 4                      No corresponde         1
# ...                               ...       ...
# 25155  Otras relaciones no familiares         1
# 25156                  No corresponde         1
# 25157                 Conyuge/ pareja         1
# 25158                  No corresponde         1
# 25159                    Sin relación         1
#
# [25160 rows x 20 columns]

# %% [markdown]
# ### Graficando los datos en escala original

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# %%
fig = plt.figure(figsize=(15, 5))
sns.pairplot(datos)
plt.show()

# %% [markdown]
# ### Distribución de los datos originales

# %%
for column in datos.columns:
    try:
        sns.histplot(datos[column])
        plt.show()
    except:
        continue

# %% [markdown]
# ## Escalamiento

# %% [markdown]
# ### Escala en función del mínimo y máximo

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Separar características numéricas y categóricas
numeric_features = datos.select_dtypes(include=['int', 'float']).columns

# Escalamiento de características numéricas
scaler = MinMaxScaler()
scaled_data = datos.copy()
scaled_data[numeric_features] = scaler.fit_transform(datos[numeric_features])

# %%
# convierte vectores de numpy a DataFrames para graficarlos
datos_escalados = pd.DataFrame(scaled_data, columns=datos.columns)

# %%
datos_escalados
# Out:
#        Id_hecho         provincia         localidad  anio       mes  \
# 0      0.000000           NEUQUEN          Plottier   0.0  0.000000
# 1      0.000000           NEUQUEN          Plottier   0.0  0.000000
# 2      0.000000           NEUQUEN          Plottier   0.0  0.000000
# 3      0.000000           NEUQUEN          Plottier   0.0  0.000000
# 4      0.000060           NEUQUEN         Cutral Có   0.0  0.000000
# ...         ...               ...               ...   ...       ...
# 25155  0.991989      BUENOS AIRES  Florencio Varela   1.0  0.909091
# 25156  0.999402  TIERRA DEL FUEGO           Ushuaia   1.0  0.545455
# 25157  0.999402  TIERRA DEL FUEGO           Ushuaia   1.0  0.545455
# 25158  1.000000        ENTRE RIOS         Concordia   0.0  1.000000
# 25159  1.000000        ENTRE RIOS         Concordia   0.0  1.000000
#
#                  tipo_lugar   tipo_lugar_ampliado motivo_origen_registro  \
# 0      Domicilio particular  Domicilio particular  Intervención policial
# 1      Domicilio particular  Domicilio particular  Intervención policial
# 2      Domicilio particular  Domicilio particular  Intervención policial
# 3      Domicilio particular  Domicilio particular  Intervención policial
# 4               Vía pública           Vía pública  Intervención policial
# ...                     ...                   ...                    ...
# 25155           Vía pública           Vía pública  Intervención policial
# 25156  Domicilio particular  Domicilio particular  Intervención policial
# 25157  Domicilio particular  Domicilio particular  Intervención policial
# 25158           Vía pública           Vía pública  Intervención policial
# 25159           Vía pública           Vía pública  Intervención policial
#
#       fecha_hecho hora_hecho            tipo_persona_id tipo_persona  \
# 0       14/1/2017   22:38:00  Imputado idRegistro 12929     Imputado
# 1       14/1/2017   22:38:00  Imputado idRegistro 12930     Imputado
# 2       14/1/2017   22:38:00  Imputado idRegistro 12931     Imputado
# 3       14/1/2017   22:38:00   Víctima idRegistro 12235      Víctima
# 4        7/1/2017   10:35:00  Imputado idRegistro 12932     Imputado
# ...           ...        ...                        ...          ...
# 25155  10/11/2021   11:11:11   Víctima idRegistro 29888      Víctima
# 25156    4/7/2021   12:00:00  Imputado idRegistro 32993     Imputado
# 25157    4/7/2021   12:00:00   Víctima idRegistro 30020      Víctima
# 25158  25/12/2017   11:11:11  Imputado idRegistro 33004     Imputado
# 25159  25/12/2017   11:11:11   Víctima idRegistro 30031      Víctima
#
#          sexo_victima tr_edad_victima   clase_victima  sexo_inculpado  \
# 0      No corresponde  No corresponde  No corresponde       Masculino
# 1      No corresponde  No corresponde  No corresponde       Masculino
# 2      No corresponde  No corresponde  No corresponde       Masculino
# 3           Masculino           45-49           Civil  No corresponde
# 4      No corresponde  No corresponde  No corresponde       Masculino
# ...               ...             ...             ...             ...
# 25155       Masculino           45-49           Civil  No corresponde
# 25156  No corresponde  No corresponde  No corresponde        Femenino
# 25157       Masculino           25-29           Civil  No corresponde
# 25158  No corresponde  No corresponde  No corresponde       Masculino
# 25159       Masculino           35-39           Civil  No corresponde
#
#       tr_edad_inculpado relacion_inculpado_victima  \
# 0        Sin determinar               Sin relación
# 1        Sin determinar               Sin relación
# 2        Sin determinar               Sin relación
# 3        No corresponde             No corresponde
# 4                 30-34               Sin relación
# ...                 ...                        ...
# 25155    No corresponde             No corresponde
# 25156             25-29            Conyuge/ pareja
# 25157    No corresponde             No corresponde
# 25158             30-34               Sin relación
# 25159    No corresponde             No corresponde
#
#            relacion_victima_inculpado  cant_vic
# 0                      No corresponde       0.0
# 1                      No corresponde       0.0
# 2                      No corresponde       0.0
# 3                        Sin relación       0.0
# 4                      No corresponde       0.0
# ...                               ...       ...
# 25155  Otras relaciones no familiares       0.0
# 25156                  No corresponde       0.0
# 25157                 Conyuge/ pareja       0.0
# 25158                  No corresponde       0.0
# 25159                    Sin relación       0.0
#
# [25160 rows x 20 columns]

# %% [markdown]
# ## Codificacion de datos categoricos

# %%
#Observacion de los tipos de datos por columna, con el fin de encontrar aquellas con datos categoricos/object
print(datos.dtypes)
# Out:
# Id_hecho                       int64
# provincia                     object
# localidad                     object
# anio                           int64
# mes                            int64
# tipo_lugar                    object
# tipo_lugar_ampliado           object
# motivo_origen_registro        object
# fecha_hecho                   object
# hora_hecho                    object
# tipo_persona_id               object
# tipo_persona                  object
# sexo_victima                  object
# tr_edad_victima               object
# clase_victima                 object
# sexo_inculpado                object
# tr_edad_inculpado             object
# relacion_inculpado_victima    object
# relacion_victima_inculpado    object
# cant_vic                       int64
# dtype: object

# %% [markdown]
# ### Categoricos ordinales

# %%
##No hay

# %% [markdown]
# ### Categoricos nominales

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Seleccionar las columnas de tipo object
object_columns = datos_escalados.select_dtypes(include=['object']).columns.copy()

# Iterar sobre las columnas seleccionadas y aplicar la codificación
for column in object_columns:
    encoder = LabelEncoder()
    datos_escalados[column] = encoder.fit_transform(datos_escalados[column].astype(str))

# %%
datos

# %% [markdown]
# ## Reduccion de dimencionalidad

# %%
from sklearn.feature_selection import SelectPercentile, chi2

# %%
def reduccion(data, lista_columnas, porcentaje):
    y = data[lista_columnas].copy()  # Variable objetivo numérica
    X = data.drop(columns=lista_columnas).copy()  # DataFrame con características numéricas excepto la variable objetivo
    
    # Aplicar la reducción de dimensionalidad
    selector = SelectPercentile(chi2, percentile=porcentaje)
    datos_reducidos = selector.fit_transform(X, y)
    
    # Obtener las columnas seleccionadas
    columnas_seleccionadas = X.columns[selector.get_support()]
    
    # Crear el DataFrame reducido con las columnas seleccionadas
    df_reducido = pd.DataFrame(datos_reducidos, columns=columnas_seleccionadas)
    
    # Agregar la columna 'sexo_victima' al DataFrame reducido
    df_reducido[lista_columnas] = y
    
    return df_reducido

# %%
print(disp(datos_escalados))
# Out:
#        Id_hecho  provincia  localidad  anio       mes  tipo_lugar  \
# 0      0.000000         14        616   0.0  0.000000           2
# 1      0.000000         14        616   0.0  0.000000           2
# 2      0.000000         14        616   0.0  0.000000           2
# 3      0.000000         14        616   0.0  0.000000           2
# 4      0.000060         14        231   0.0  0.000000           6
# ...         ...        ...        ...   ...       ...         ...
# 25155  0.991989          0        298   1.0  0.909091           6
# 25156  0.999402         22        845   1.0  0.545455           2
# 25157  0.999402         22        845   1.0  0.545455           2
# 25158  1.000000          7        206   0.0  1.000000           6
# 25159  1.000000          7        206   0.0  1.000000           6
#
#        tipo_lugar_ampliado  motivo_origen_registro  fecha_hecho  hora_hecho  \
# 0                       11                       1          298         785
# 1                       11                       1          298         785
# 2                       11                       1          298         785
# 3                       11                       1          298         785
# 4                       22                       1         1632         368
# ...                    ...                     ...          ...         ...
# 25155                   22                       1           73         385
# 25156                   11                       1         1502         410
# 25157                   11                       1         1502         410
# 25158                   22                       1         1028         385
# 25159                   22                       1         1028         385
#
#        tipo_persona_id  tipo_persona  sexo_victima  tr_edad_victima  \
# 0                    0             0             2               19
# 1                    1             0             2               19
# 2                    2             0             2               19
# 3                13646             1             1                8
# 4                    3             0             2               19
# ...                ...           ...           ...              ...
# 25155            25137             1             1                8
# 25156            13571             0             2               19
# 25157            25141             1             1                3
# 25158            13573             0             2               19
# 25159            25142             1             1                5
#
#        clase_victima  sexo_inculpado  tr_edad_inculpado  \
# 0                  2               1                 19
# 1                  2               1                 19
# 2                  2               1                 19
# 3                  0               2                 18
# 4                  2               1                  4
# ...              ...             ...                ...
# 25155              0               2                 18
# 25156              2               0                  3
# 25157              0               2                 18
# 25158              2               1                  4
# 25159              0               2                 18
#
#        relacion_inculpado_victima  relacion_victima_inculpado  cant_vic
# 0                              12                           7       0.0
# 1                              12                           7       0.0
# 2                              12                           7       0.0
# 3                               7                          12       0.0
# 4                              12                           7       0.0
# ...                           ...                         ...       ...
# 25155                           7                           8       0.0
# 25156                           1                           7       0.0
# 25157                           7                           1       0.0
# 25158                          12                           7       0.0
# 25159                           7                          12       0.0
#
# [25160 rows x 20 columns]
# None

# %% [markdown]
# Se reduce la dimensionalidad del dataframe en base a las columnas que se utilizaran para responder cada pregunta

# %% [markdown]
# - 1. ¿Cuál es la proporción de víctimas masculinas y femeninas en los delitos registrados?

# %%
datos_sexo_victima = reduccion(datos_escalados, 'sexo_victima', 5)

# %%
#Se recupera la codificacion categorica para la columna "sexo_victima"
datos_sexo_victima.sexo_victima = datos.sexo_victima
datos_sexo_victima['Id_hecho'] = datos.Id_hecho
# Out:
#        tipo_persona_id    sexo_victima
# 0                  0.0  No corresponde
# 1                  1.0  No corresponde
# 2                  2.0  No corresponde
# 3              13646.0       Masculino
# 4                  3.0  No corresponde
# ...                ...             ...
# 25155          25137.0       Masculino
# 25156          13571.0  No corresponde
# 25157          25141.0       Masculino
# 25158          13573.0  No corresponde
# 25159          25142.0       Masculino
#
# [25160 rows x 2 columns]
# None

# %%
print(disp(datos_sexo_victima))
# Out:
#        tipo_persona_id    sexo_victima  Id_hecho
# 0                  0.0  No corresponde     11535
# 1                  1.0  No corresponde     11535
# 2                  2.0  No corresponde     11535
# 3              13646.0       Masculino     11535
# 4                  3.0  No corresponde     11536
# ...                ...             ...       ...
# 25155          25137.0       Masculino     28129
# 25156          13571.0  No corresponde     28253
# 25157          25141.0       Masculino     28253
# 25158          13573.0  No corresponde     28263
# 25159          25142.0       Masculino     28263
#
# [25160 rows x 3 columns]
# None

# %%
#Se guarda el dataframe como CSV
ruta_destino = "../../../datos/procesados/preparacion01_datos_sexo_victima.csv"  # Ruta y nombre del archivo de destino
datos_sexo_victima.to_csv(ruta_destino, index=False)

# %% [markdown]
# - 2. ¿Cuáles son los departamentos con mayor número de delitos?

# %%
datos_deptos_delitos = reduccion(datos_escalados, 'localidad', 5)

# %%
#Se recupera la codificacion categorica para la columna "localidad"
datos_deptos_delitos['localidad'] = datos.localidad
datos_deptos_delitos['Id_hecho'] = datos.Id_hecho

# %%
print(disp(datos_deptos_delitos))
# Out:
#        tipo_persona_id         localidad  Id_hecho
# 0                  0.0          Plottier     11535
# 1                  1.0          Plottier     11535
# 2                  2.0          Plottier     11535
# 3              13646.0          Plottier     11535
# 4                  3.0         Cutral Có     11536
# ...                ...               ...       ...
# 25155          25137.0  Florencio Varela     28129
# 25156          13571.0           Ushuaia     28253
# 25157          25141.0           Ushuaia     28253
# 25158          13573.0         Concordia     28263
# 25159          25142.0         Concordia     28263
#
# [25160 rows x 3 columns]
# None

# %%
#Se guarda el dataframe como CSV
ruta_destino = "../../../datos/procesados/preparacion02_datos_deptos_delitos.csv"  # Ruta y nombre del archivo de destino
datos_deptos_delitos.to_csv(ruta_destino, index=False)

# %% [markdown]
# - 3. ¿Cuáles son los motivos más comunes que originaron el registro de un delito?

# %%
datos_motivos_delitos = reduccion(datos_escalados, 'motivo_origen_registro', 5)

# %%
#Se recupera la codificacion categorica para la columna "localidad"
datos_motivos_delitos['motivo_origen_registro'] = datos.motivo_origen_registro
datos_motivos_delitos['Id_hecho'] = datos.Id_hecho

# %%
print(disp(datos_motivos_delitos))
# Out:
#       motivo_origen_registro  Id_hecho
# 0      Intervención policial     11535
# 1      Intervención policial     11535
# 2      Intervención policial     11535
# 3      Intervención policial     11535
# 4      Intervención policial     11536
# ...                      ...       ...
# 25155  Intervención policial     28129
# 25156  Intervención policial     28253
# 25157  Intervención policial     28253
# 25158  Intervención policial     28263
# 25159  Intervención policial     28263
#
# [25160 rows x 2 columns]
# None

# %%
#Se guarda el dataframe como CSV
ruta_destino = "../../../datos/procesados/preparacion03_datos_motivo_delitos.csv"  # Ruta y nombre del archivo de destino
datos_motivos_delitos.to_csv(ruta_destino, index=False)

# %% [markdown]
# - 4. ¿Existe alguna relación entre el mes del año y la cantidad de delitos?

# %%
def limpiarnan(df):
    for col in df.columns:
        for r in df.rows:
            if df[col].r == 'NaN':
                df.r.drop()

# %%
datos_fecha_delitos_anio = pd.DataFrame(datos.anio)
datos_fecha_delitos_mes = pd.DataFrame(datos.mes)
datos_fecha_delitos = pd.concat([datos_fecha_delitos_anio, datos_fecha_delitos_mes])
datos_fecha_delitos['Id_hecho'] = datos.Id_hecho

# %%
datos_fecha_delitos.apply(limpiarnan)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_74716/3615072269.py in <module>
# ----> 1 datos_fecha_delitos.apply(limpiarnan)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9566             kwargs=kwargs,
#    9567         )
# -> 9568         return op.apply().__finalize__(self, method="apply")
#    9569
#    9570     def applymap(
#
# ~/.local/lib/python3.10/site-packages/pandas/core/apply.py in apply(self)
#     762             return self.apply_raw()
#     763
# --> 764         return self.apply_standard()
#     765
#     766     def agg(self):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/apply.py in apply_standard(self)
#     889
#     890     def apply_standard(self):
# --> 891         results, res_index = self.apply_series_generator()
#     892
#     893         # wrap results
#
# ~/.local/lib/python3.10/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     905             for i, v in enumerate(series_gen):
#     906                 # ignore SettingWithCopy here in case the user mutates
# --> 907                 results[i] = self.f(v)
#     908                 if isinstance(results[i], ABCSeries):
#     909                     # If we have a view on v, we need to make a copy because
#
# /tmp/ipykernel_74716/2386897040.py in limpiarnan(df)
#       1 def limpiarnan(df):
# ----> 2     for col in df.columns:
#       3         for r in df.rows:
#       4             if df[col].r == 'NaN':
#       5                 df.r.drop()
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
#Se eliminan todos los valores de meses NaN

datos_fecha_delitos = datos_fecha_delitos.fillna(np.nan()).dropna()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_74716/4130213278.py in <module>
#       1 #Se eliminan todos los valores de meses NaN
# ----> 2 datos_fecha_delitos = datos_fecha_delitos.fillna(np.nan()).dropna()
#
# TypeError: 'float' object is not callable

# %%
print(disp(datos_fecha_delitos))
# Out:
#          anio   mes  Id_hecho
# 0      2017.0   NaN     11535
# 1      2017.0   NaN     11535
# 2      2017.0   NaN     11535
# 3      2017.0   NaN     11535
# 4      2017.0   NaN     11536
# ...       ...   ...       ...
# 25155     NaN  11.0     28129
# 25156     NaN   7.0     28253
# 25157     NaN   7.0     28253
# 25158     NaN  12.0     28263
# 25159     NaN  12.0     28263
#
# [50320 rows x 3 columns]
# None

# %%
#Se guarda el dataframe como CSV
ruta_destino = "../../../datos/procesados/preparacion03_datos_motivo_delitos.csv"  # Ruta y nombre del archivo de destino
datos_motivos_delitos.to_csv(ruta_destino, index=False)

# %% [markdown]
# - 5. ¿Hay alguna relación entre el lugar y el género de la victima?

# %%
datos_lugar_delitos = reduccion(datos_escalados, 'tipo_lugar', 5)
datos_lugar_delitos['tipo_lugar'] = datos.tipo_lugar

datos_genero_delitos = reduccion(datos_escalados, 'sexo_victima', 5)
datos_genero_delitos['sexo_victima'] = datos.sexo_victima


datos_lugar_genero_delito = pd.concat([datos_lugar_delitos, datos_genero_delitos])
datos_lugar_genero_delito['Id_hecho'] = datos.Id_hecho

# %%
print(disp(datos_lugar_genero_delito))
# Out:
#        tipo_persona_id            tipo_lugar    sexo_victima  Id_hecho
# 0                  0.0  Domicilio particular             NaN     11535
# 1                  1.0  Domicilio particular             NaN     11535
# 2                  2.0  Domicilio particular             NaN     11535
# 3              13646.0  Domicilio particular             NaN     11535
# 4                  3.0           Vía pública             NaN     11536
# ...                ...                   ...             ...       ...
# 25155          25137.0                   NaN       Masculino     28129
# 25156          13571.0                   NaN  No corresponde     28253
# 25157          25141.0                   NaN       Masculino     28253
# 25158          13573.0                   NaN  No corresponde     28263
# 25159          25142.0                   NaN       Masculino     28263
#
# [50320 rows x 4 columns]
# None

# %%
#Se guarda el dataframe como CSV
ruta_destino = "../../../datos/procesados/preparacion04_datos_lugar_genero_v_delito.csv"  # Ruta y nombre del archivo de destino
datos_lugar_genero_delito.to_csv(ruta_destino, index=False)

# %% [markdown]
# - 6. ¿Hay alguna relación entre el lugar y el género del inculpado?

# %%
datos_lugar_genero_delito

# %%
datos_lugar_delitos = reduccion(datos_escalados, 'tipo_lugar', 5)
datos_lugar_delitos['tipo_lugar'] = datos.tipo_lugar

datos_genero_delitos = reduccion(datos_escalados, 'sexo_inculpado', 5)
datos_genero_delitos['sexo_inculpado'] = datos.sexo_inculpado

datos_lugar_genero_delito = pd.concat([datos_lugar_delitos, datos_genero_delitos])

# %%
print(disp(datos_lugar_genero_delito))
# Out:
#        tipo_persona_id            tipo_lugar  sexo_inculpado
# 0                  0.0  Domicilio particular             NaN
# 1                  1.0  Domicilio particular             NaN
# 2                  2.0  Domicilio particular             NaN
# 3              13646.0  Domicilio particular             NaN
# 4                  3.0           Vía pública             NaN
# ...                ...                   ...             ...
# 25155          25137.0                   NaN  No corresponde
# 25156          13571.0                   NaN        Femenino
# 25157          25141.0                   NaN  No corresponde
# 25158          13573.0                   NaN       Masculino
# 25159          25142.0                   NaN  No corresponde
#
# [50320 rows x 3 columns]
# None

# %%
#Se guarda el dataframe como CSV
ruta_destino = "../../../datos/procesados/preparacion04_datos_lugar_genero_v_delito.csv"  # Ruta y nombre del archivo de destino
datos_lugar_genero_delito.to_csv(ruta_destino, index=False)

# %% [markdown]
# - 6. ¿Hay alguna relación entre el lugar y el género del inculpado?
